# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/Assignments/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here

import pandas as pd
import nltk
from nltk import ngrams
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter

# Load the IMDb movie reviews dataset
df = pd.read_csv('/content/imdb_movie_reviews.csv')

# Select the first 100 reviews (you can adjust the number as needed)
reviews = df['Review'][:100]

# Function to tokenize and generate N-grams
def generate_ngrams(text, n):
    tokens = nltk.word_tokenize(text)
    n_grams = ngrams(tokens, n)
    return [' '.join(gram) for gram in n_grams]

# Function to count N-grams frequency
def count_ngrams(reviews, n):
    all_ngrams = []
    for review in reviews:
        ngrams_review = generate_ngrams(review, n)
        all_ngrams.extend(ngrams_review)
    return Counter(all_ngrams)

# Function to calculate bigram probabilities
def calculate_bigram_probabilities(reviews):
    bigrams_count = count_ngrams(reviews, 2)
    unigrams_count = count_ngrams(reviews, 1)

    bigram_probabilities = {}
    for bigram, count in bigrams_count.items():
        unigram = bigram.split()[0]
        probability = count / unigrams_count[unigram]
        bigram_probabilities[bigram] = probability

    return bigram_probabilities

# Function to extract and calculate noun phrase probabilities
def calculate_noun_phrase_probabilities(reviews):
    noun_phrases = []
    for review in reviews:
        tokens = nltk.word_tokenize(review)
        tagged_tokens = pos_tag(tokens)
        grammar = "NP: {<DT>?<JJ>*<NN>}"
        cp = nltk.RegexpParser(grammar)
        tree = cp.parse(tagged_tokens)

        for subtree in tree.subtrees(filter=lambda x: x.label() == 'NP'):
            noun_phrase = ' '.join([word for word, tag in subtree.leaves()])
            noun_phrases.append(noun_phrase)

    noun_phrase_counts = Counter(noun_phrases)
    max_counts = max(noun_phrase_counts.values())

    noun_phrase_probabilities = {}
    for review in reviews:
        tokens = nltk.word_tokenize(review)
        review_noun_phrases = [word for word in tokens if word in noun_phrases]
        review_counts = Counter(review_noun_phrases)
        probabilities = {noun_phrase: count / max_counts for noun_phrase, count in review_counts.items()}
        noun_phrase_probabilities[review] = probabilities

    return noun_phrase_probabilities

# Count N-grams (N=3)
ngram_counts = count_ngrams(reviews, 3)
print("N-gram Counts:")
print(ngram_counts)
print("\n")

# Calculate bigram probabilities
bigram_probabilities = calculate_bigram_probabilities(reviews)
print("Bigram Probabilities:")
print(bigram_probabilities)
print("\n")

# Extract and calculate noun phrase probabilities
noun_phrase_probabilities = calculate_noun_phrase_probabilities(reviews)
df_noun_phrases = pd.DataFrame.from_dict(noun_phrase_probabilities, orient='index')
df_noun_phrases.fillna(0, inplace=True)  # Fill NaN with 0 for better representation
print("Noun Phrase Probabilities:")
print(df_noun_phrases)
# Out:
# N-gram Counts:
# Counter({'The Shawshank Redemption': 18, 'one of the': 15, '! ! !': 11, '* * *': 10, '-- -- --': 10, '. It is': 8, 'this movie is': 8, 'of all time': 8, ', and the': 8, 'of the best': 8, 'of the film': 7, ', it is': 7, 'Shawshank Redemption .': 6, ', the film': 6, 'the story of': 6, "`` Red ''": 6, 'is one of': 6, 'of the most': 6, 'some of the': 6, 'this movie ,': 6, "Red '' Redding": 5, ", it 's": 5, 'If you have': 5, '. This is': 5, "the film 's": 5, 'of the greatest': 5, '( Morgan Freeman': 5, 'Morgan Freeman )': 5, 'Shawshank Redemption is': 4, 'and Morgan Freeman': 4, '. However ,': 4, 'in the film': 4, 'in the world': 4, 'of the movie': 4, "you do n't": 4, 'film of all': 4, '. If you': 4, "you have n't": 4, "have n't seen": 4, '`` The Shawshank': 4, '. But the': 4, '. It has': 4, 'the movie is': 4, ". It 's": 4, ', and I': 4, 'movie , but': 4, '( Tim Robbins': 4, ', `` The': 4, "'' , ``": 4, 'directed by Frank': 3, 'by Frank Darabont': 3, 'Rita Hayworth and': 3, 'Tim Robbins and': 3, 'Robbins and Morgan': 3, 'Morgan Freeman ,': 3, 'of Andy Dufresne': 3, 'Andy Dufresne (': 3, 'his wife and': 3, 'wife and her': 3, 'and her lover': 3, 'her lover .': 3, "'' Redding (": 3, 'the box office': 3, 'modern day classic': 3, ', but most': 3, 'most of all': 3, ', this movie': 3, 'the best film': 3, 'best film of': 3, "it is n't": 3, "n't seen it": 3, ', no matter': 3, 'no matter how': 3, 'matter how many': 3, 'it is a': 3, ', this is': 3, "'' and ``": 3, '. The story': 3, 'This movie is': 3, '. This movie': 3, 'of this movie': 3, 'never gives up': 3, 'Ellis Boyd ``': 3, 'Boyd `` Red': 3, 'the rest of': 3, ', the movie': 3, "there 's a": 3, 'the film is': 3, ', and a': 3, 'message of hope': 3, 'of Stephen King': 3, 'I am not': 3, 'on the IMDb': 3, ', but it': 3, "I do n't": 3, 'this film ,': 3, 'seen this movie': 3, 'the fact that': 3, 'every time I': 3, 'Tim Robbins )': 3, 'Redding ( Morgan': 3, 'to see it': 3, 'about the movie': 3, 'the same time': 3, "Shawshank Redemption ''": 3, 'The Green Mile': 3, '. The Shawshank': 3, 'look at the': 3, "I ca n't": 3, 'written and directed': 2, 'and directed by': 2, 'It is an': 2, 'novella Rita Hayworth': 2, 'Hayworth and Shawshank': 2, 'and Shawshank Redemption': 2, 'story of Andy': 2, '( Robbins )': 2, ') , a': 2, 'sentenced to two': 2, 'Shawshank State Prison': 2, 'murdering his wife': 2, 'for all of': 2, ', Shawshank Redemption': 2, 'box office .': 2, 'the film received': 2, ', though ,': 2, 'of prison life': 2, 'the film with': 2, 'film with a': 2, ', and so': 2, ', but that': 2, "it 's the": 2, '. Bob Gunton': 2, 'Bob Gunton is': 2, 'as Warden Norton': 2, 'Warden Norton ,': 2, 'James Whitmore is': 2, 'as the ``': 2,
031744, 'State Prison': 1.0, 'Prison for': 0.5, 'for apparently': 0.015151515151515152, 'apparently murdering': 0.5, 'murdering his': 1.0, 'his wife': 0.09803921568627451, 'wife and': 0.375, 'and her': 0.013157894736842105, 'her lover': 0.75, 'lover .': 1.0, '. Andy': 0.02046783625730994, 'Andy finds': 0.05, 'finds it': 0.16666666666666666, 'it tough': 0.007936507936507936, 'tough going': 0.3333333333333333, 'going but': 0.14285714285714285, 'but finds': 0.019230769230769232, 'finds solace': 0.16666666666666666, 'solace in': 0.3333333333333333, 'in the': 0.23484848484848486, 'the friendship': 0.0023584905660377358, 'friendship he': 0.16666666666666666, 'he forms': 0.02702702702702703, 'forms with': 1.0, 'with fellow': 0.018518518518518517, 'fellow inmate': 0.75, 'inmate Ellis': 0.2, 'Ellis ``': 0.14285714285714285, '`` Red': 0.12244897959183673, "Red ''": 0.2857142857142857, "'' Redding": 0.09803921568627451, 'Redding (': 0.5714285714285714, '( Freeman': 0.03333333333333333, 'Freeman )': 0.21428571428571427, ') .': 0.06451612903225806, '. While': 0.011695906432748537, 'While things': 0.25, 'things start': 0.125, 'start to': 0.5, 'to pick': 0.005917159763313609, 'pick up': 1.0, 'up when': 0.06666666666666667, 'when the': 0.06666666666666667, 'the warden': 0.01179245283018868, 'warden finds': 0.14285714285714285, 'finds Andy': 0.16666666666666666, 'Andy a': 0.05, 'a prison': 0.028708133971291867, 'prison job': 0.02857142857142857, 'job more': 0.5, 'more befitting': 0.07692307692307693, 'befitting his': 1.0, 'his talents': 0.0196078431372549, 'talents as': 1.0, 'as a': 0.09876543209876543, 'banker .': 0.2, '. However': 0.011695906432748537, 'However ,': 1.0, 'the arrival': 0.0023584905660377358, 'arrival of': 1.0, 'of another': 0.0037735849056603774, 'another inmate': 0.25, 'inmate is': 0.2, 'is going': 0.005917159763313609, 'going to': 0.42857142857142855, 'to vastly': 0.005917159763313609, 'vastly change': 1.0, 'change things': 1.0, 'things for': 0.25, 'for all': 0.030303030303030304, 'all of': 0.1282051282051282, 'of them.There': 0.0037735849056603774, 'them.There was': 1.0, 'was no': 0.025, 'no fanfare': 0.07142857142857142, 'fanfare or': 1.0, 'or bunting': 0.043478260869565216, 'bunting put': 1.0, 'put out': 0.25, 'out for': 0.1111111111111111, 'for the': 0.16 ...
#
#
# Noun Phrase Probabilities:
#                                                         King   novella  \
# The Shawshank Redemption is written and directe...  0.027778  0.027778
# In its Oscar year, Shawshank Redemption (writte...  0.027778  0.027778
# Shawshank Redemption is without doubt one of th...  0.083333  0.000000
# One of the finest films made in recent years. I...  0.027778  0.000000
# Misery and Stand By Me were the best adaptation...  0.083333  0.000000
# I've lost count of the number of times I have s...  0.055556  0.000000
# Based on a novella by Stephen King, this is bet...  0.055556  0.027778
# The Shawshank Redemption is without a doubt one...  0.055556  0.027778
# None of the usual otherworld creatures that pop...  0.055556  0.000000
# Can Hollywood, usually creating things for ente...  0.055556  0.138889
# "The Shawshank Redemption" should have won Best...  0.027778  0.000000
# One of my favorite movies ever,The Shawshank Re...  0.027778  0.000000
# It is no wonder that the film has such a high r...  0.000000  0.000000
# Well I guess I'm a little late to the party as ...  0.000000  0.027778
# Whenever I talk about this movie with my friend...  0.000000  0.055556
# I have never seen such an amazing film since I ...  0.000000  0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...  0.000000  0.055556
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...  0.000000  0.000000
# The Shawshank Redemption has great performances...  0.000000  0.000000
# The reason I became a member of this database i...  0.000000  0.000000
# This movie is not your ordinary Hollywood flick...  0.000000  0.055556
# There's a reason this is rated the #1 . It is t...  0.000000  0.000000
# The best movie in history and the best ending i...  0.000000  0.000000
#
#                                                         wife     lover  \
# The Shawshank Redemption is written and directe...  0.027778  0.027778
# In its Oscar year, Shawshank Redemption (writte...  0.000000  0.000000
# Shawshank Redemption is without doubt one of th...  0.000000  0.000000
# One of the finest films made in recent years. I...  0.000000  0.000000
# Misery and Stand By Me were the best adaptation...  0.000000  0.000000
# I've lost count of the number of times I have s...  0.000000  0.000000
# Based on a novella by Stephen King, this is bet...  0.000000  0.000000
# The Shawshank Redemption is without a doubt one...  0.027778  0.000000
# None of the usual otherworld creatures that pop...  0.027778  0.000000
# Can Hollywood, usually creating things for ente...  0.027778  0.027778
# "The Shawshank Redemption" should have won Best...  0.000000  0.000000
# One of my favorite movies ever,The Shawshank Re...  0.000000  0.000000
# It is no wonder that the film has such a high r...  0.000000  0.000000
# I'm trying to save you money; this is the last ...  0.000000  0.000000
# Two imprisoned men (Tim Robbins and Morgan Free...  0.000000  0.000000
# Well I guess I'm a little late to the party as ...  0.000000  0.000000
# Whenever I talk about this movie with my friend...  0.000000  0.000000
# I have never seen such an amazing film since I ...  0.000000  0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...  0.000000  0.000000
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...  0.083333  0.000000
# The Shawshank Redemption has great performances...  0.000000  0.000000
# The reason I became a member of this database i...  0.000000  0.000000
# This movie is not your ordinary Hollywood flick...  0.027778  0.027778
# There's a reason this is rated the #1 . It is t...  0.000000  0.000000
# The best movie in history and the best ending i...  0.000000  0.000000
#
#                                                       solace  friendship  ...  \
# The Shawshank Redemption is written and directe...  0.027778    0.055556  ...
# In its Oscar year, Shawshank Redemption (writte...  0.000000    0.027778  ...
# Shawshank Redemption is without doubt one of th...  0.000000    0.000000  ...
# One of the finest films made in recent years. I...  0.000000    0.000000  ...
# Misery and Stand By Me were the best adaptation...  0.000000    0.000000  ...
# I've lost count of the number of times I have s...  0.000000    0.000000  ...
# Based on a novella by Stephen King, this is bet...  0.000000    0.000000  ...
# The Shawshank Redemption is without a doubt one...  0.000000    0.000000  ...
# None of the usual otherworld creatures that pop...  0.000000    0.000000  ...
# Can Hollywood, usually creating things for ente...  0.000000    0.000000  ...
# "The Shawshank Redemption" should have won Best...  0.000000    0.000000  ...
# One of my favorite movies ever,The Shawshank Re...  0.027778    0.000000  ...
# It is no wonder that the film has such a high r...  0.000000    0.027778  ...
# I'm trying to save you money; this is the last ...  0.000000    0.000000  ...
# Two imprisoned men (Tim Robbins and Morgan Free...  0.027778    0.000000  ...
# Well I guess I'm a little late to the party as ...  0.000000    0.000000  ...
# Whenever I talk about this movie with my friend...  0.000000    0.000000  ...
# I have never seen such an amazing film since I ...  0.000000    0.000000  ...
# Shawshank Redemption, The (1994)**** (out of 4)...  0.000000    0.027778  ...
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...  0.000000    0.000000  ...
# The Shawshank Redemption has great performances...  0.000000    0.000000  ...
# The reason I became a member of this database i...  0.000000    0.000000  ...
# This movie is not your ordinary Hollywood flick...  0.000000    0.027778  ...
# There's a reason this is rated the #1 . It is t...  0.000000    0.000000  ...
# The best movie in history and the best ending i...  0.000000    0.000000  ...
#
#                                                          awe  believer  \
# The Shawshank Redemption is written and directe...  0.000000  0.000000
# In its Oscar year, Shawshank Redemption (writte...  0.000000  0.000000
# Shawshank Redemption is without doubt one of th...  0.000000  0.000000
# One of the finest films made in recent years. I...  0.000000  0.000000
# Misery and Stand By Me were the best adaptation...  0.000000  0.000000
# I've lost count of the number of times I have s...  0.000000  0.000000
# Based on a novella by Stephen King, this is bet...  0.000000  0.000000
# The Shawshank Redemption is without a doubt one...  0.000000  0.000000
# None of the usual otherworld creatures that pop...  0.000000  0.000000
# Can Hollywood, usually creating things for ente...  0.000000  0.000000
# "The Shawshank Redemption" should have won Best...  0.000000  0.000000
# One of my favorite movies ever,The Shawshank Re...  0.000000  0.000000
# It is no wonder that the film has such a high r...  0.000000  0.000000
# I'm trying to save you money; this is the last ...  0.000000  0.000000
# Two imprisoned men (Tim Robbins and Morgan Free...  0.000000  0.000000
# Well I guess I'm a little late to the party as ...  0.000000  0.000000
# Whenever I talk about this movie with my friend...  0.000000  0.000000
# I have never seen such an amazing film since I ...  0.000000  0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...  0.000000  0.000000
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...  0.027778  0.027778
# The Shawshank Redemption has great performances...  0.000000  0.000000
# The reason I became a member of this database i...  0.000000  0.000000
# This movie is not your ordinary Hollywood flick...  0.000000  0.000000
# There's a reason this is rated the #1 . It is t...  0.000000  0.000000
# The best movie in history and the best ending i...  0.000000  0.000000
#
#                                                     environment  territory  \
# The Shawshank Redemption is written and directe...     0.000000   0.000000
# In its Oscar year, Shawshank Redemption (writte...     0.000000   0.000000
# Shawshank Redemption is without doubt one of th...     0.000000   0.000000
# One of the finest films made in recent years. I...     0.000000   0.000000
# Misery and Stand By Me were the best adaptation...     0.000000   0.000000
# I've lost count of the number of times I have s...     0.000000   0.000000
# Based on a novella by Stephen King, this is bet...     0.000000   0.000000
# The Shawshank Redemption is without a doubt one...     0.000000   0.000000
# None of the usual otherworld creatures that pop...     0.000000   0.000000
# Can Hollywood, usually creating things for ente...     0.000000   0.000000
# "The Shawshank Redemption" should have won Best...     0.000000   0.000000
# One of my favorite movies ever,The Shawshank Re...     0.000000   0.000000
# It is no wonder that the film has such a high r...     0.000000   0.000000
# I'm trying to save you money; this is the last ...     0.000000   0.000000
# Two imprisoned men (Tim Robbins and Morgan Free...     0.000000   0.000000
# Well I guess I'm a little late to the party as ...     0.000000   0.000000
# Whenever I talk about this movie with my friend...     0.000000   0.000000
# I have never seen such an amazing film since I ...     0.000000   0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...     0.000000   0.000000
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...     0.027778   0.027778
# The Shawshank Redemption has great performances...     0.000000   0.000000
# The reason I became a member of this database i...     0.000000   0.000000
# This movie is not your ordinary Hollywood flick...     0.000000   0.000000
# There's a reason this is rated the #1 . It is t...     0.000000   0.000000
# The best movie in history and the best ending i...     0.000000   0.000000
#
#                                                     /DISFRUTELA        en  \
# The Shawshank Redemption is written and directe...     0.000000  0.000000
# In its Oscar year, Shawshank Redemption (writte...     0.000000  0.000000
# Shawshank Redemption is without doubt one of th...     0.000000  0.000000
# One of the finest films made in recent years. I...     0.000000  0.000000
# Misery and Stand By Me were the best adaptation...     0.000000  0.000000
# I've lost count of the number of times I have s...     0.000000  0.000000
# Based on a novella by Stephen King, this is bet...     0.000000  0.000000
# The Shawshank Redemption is without a doubt one...     0.000000  0.000000
# None of the usual otherworld creatures that pop...     0.000000  0.000000
# Can Hollywood, usually creating things for ente...     0.000000  0.000000
# "The Shawshank Redemption" should have won Best...     0.000000  0.000000
# One of my favorite movies ever,The Shawshank Re...     0.000000  0.000000
# It is no wonder that the film has such a high r...     0.000000  0.000000
# I'm trying to save you money; this is the last ...     0.000000  0.000000
# Two imprisoned men (Tim Robbins and Morgan Free...     0.000000  0.000000
# Well I guess I'm a little late to the party as ...     0.000000  0.000000
# Whenever I talk about this movie with my friend...     0.000000  0.000000
# I have never seen such an amazing film since I ...     0.000000  0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...     0.000000  0.000000
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...     0.027778  0.027778
# The Shawshank Redemption has great performances...     0.000000  0.000000
# The reason I became a member of this database i...     0.000000  0.000000
# This movie is not your ordinary Hollywood flick...     0.000000  0.000000
# There's a reason this is rated the #1 . It is t...     0.000000  0.000000
# The best movie in history and the best ending i...     0.000000  0.000000
#
#                                                     career.Bravo    cinema  \
# The Shawshank Redemption is written and directe...      0.000000  0.000000
# In its Oscar year, Shawshank Redemption (writte...      0.000000  0.000000
# Shawshank Redemption is without doubt one of th...      0.000000  0.000000
# One of the finest films made in recent years. I...      0.000000  0.000000
# Misery and Stand By Me were the best adaptation...      0.000000  0.000000
# I've lost count of the number of times I have s...      0.000000  0.000000
# Based on a novella by Stephen King, this is bet...      0.000000  0.000000
# The Shawshank Redemption is without a doubt one...      0.000000  0.000000
# None of the usual otherworld creatures that pop...      0.000000  0.000000
# Can Hollywood, usually creating things for ente...      0.000000  0.000000
# "The Shawshank Redemption" should have won Best...      0.000000  0.000000
# One of my favorite movies ever,The Shawshank Re...      0.027778  0.000000
# It is no wonder that the film has such a high r...      0.000000  0.000000
# I'm trying to save you money; this is the last ...      0.000000  0.000000
# Two imprisoned men (Tim Robbins and Morgan Free...      0.000000  0.000000
# Well I guess I'm a little late to the party as ...      0.000000  0.000000
# Whenever I talk about this movie with my friend...      0.000000  0.000000
# I have never seen such an amazing film since I ...      0.000000  0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...      0.000000  0.000000
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...      0.000000  0.000000
# The Shawshank Redemption has great performances...      0.000000  0.000000
# The reason I became a member of this database i...      0.000000  0.027778
# This movie is not your ordinary Hollywood flick...      0.000000  0.000000
# There's a reason this is rated the #1 . It is t...      0.000000  0.000000
# The best movie in history and the best ending i...      0.000000  0.000000
#
#                                                     struggle   meaning
# The Shawshank Redemption is written and directe...  0.000000  0.000000
# In its Oscar year, Shawshank Redemption (writte...  0.000000  0.000000
# Shawshank Redemption is without doubt one of th...  0.000000  0.000000
# One of the finest films made in recent years. I...  0.000000  0.000000
# Misery and Stand By Me were the best adaptation...  0.000000  0.000000
# I've lost count of the number of times I have s...  0.000000  0.000000
# Based on a novella by Stephen King, this is bet...  0.000000  0.000000
# The Shawshank Redemption is without a doubt one...  0.000000  0.000000
# None of the usual otherworld creatures that pop...  0.000000  0.000000
# Can Hollywood, usually creating things for ente...  0.000000  0.000000
# "The Shawshank Redemption" should have won Best...  0.000000  0.000000
# One of my favorite movies ever,The Shawshank Re...  0.000000  0.000000
# It is no wonder that the film has such a high r...  0.000000  0.000000
# I'm trying to save you money; this is the last ...  0.000000  0.000000
# Two imprisoned men (Tim Robbins and Morgan Free...  0.000000  0.000000
# Well I guess I'm a little late to the party as ...  0.000000  0.000000
# Whenever I talk about this movie with my friend...  0.000000  0.000000
# I have never seen such an amazing film since I ...  0.000000  0.000000
# Shawshank Redemption, The (1994)**** (out of 4)...  0.000000  0.000000
# From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLOM...  0.000000  0.000000
# The Shawshank Redemption has great performances...  0.000000  0.000000
# The reason I became a member of this database i...  0.055556  0.027778
# This movie is not your ordinary Hollywood flick...  0.000000  0.000000
# There's a reason this is rated the #1 . It is t...  0.000000  0.000000
# The best movie in history and the best ending i...  0.000000  0.000000
#
# [25 rows x 312 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the IMDb movie reviews dataset
df = pd.read_csv('/content/imdb_movie_reviews.csv')

# Select the first 100 reviews (you can adjust the number as needed)
reviews = df['Review'][:100]

# Design a query
query = "An Outstanding movie with a haunting performance and best character development"

# Function to calculate cosine similarity between query and documents
def rank_documents(query, documents):
    # Combine the query with the existing documents
    all_texts = [query] + documents.tolist()

    # Create the TF-IDF matrix
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(all_texts)

    # Calculate cosine similarity
    cosine_similarities = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1:]).flatten()

    # Create a DataFrame with document indices and corresponding cosine similarities
    result_df = pd.DataFrame({'Document': range(1, len(cosine_similarities) + 1),
                              'Cosine Similarity': cosine_similarities})

    # Sort documents by cosine similarity in descending order
    result_df = result_df.sort_values(by='Cosine Similarity', ascending=False).reset_index(drop=True)

    return result_df

# Rank documents based on cosine similarity to the query
result_df = rank_documents(query, reviews)

# Print the ranked documents
print("Ranked Documents:")
print(result_df)
# Out:
# Ranked Documents:
#     Document  Cosine Similarity
# 0         24           0.152038
# 1          6           0.117741
# 2         10           0.104219
# 3         11           0.103365
# 4          7           0.100298
# 5          4           0.099074
# 6         12           0.079990
# 7         15           0.077561
# 8          5           0.077063
# 9         16           0.073333
# 10        21           0.070685
# 11         9           0.069212
# 12        14           0.068183
# 13        17           0.067680
# 14         8           0.065570
# 15        20           0.064710
# 16         1           0.064024
# 17        25           0.058387
# 18        23           0.054052
# 19        18           0.043918
# 20         3           0.043520
# 21         2           0.039526
# 22        22           0.038186
# 23        13           0.037972
# 24        19           0.024270

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
#
# Reference: https://jaketae.github.io/study/word2vec/

# %%
# Write your code here


import pandas as pd
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Load your dataset from assignment two
df = pd.read_csv('/content/imdb_movie_reviews.csv')

# Assuming you have a 'text' column in your dataset containing the text data
corpus = df['Review'].tolist()

# Tokenize and preprocess the text
def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens if word.isalpha()]
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return tokens

# Preprocess the entire corpus
preprocessed_corpus = [preprocess_text(text) for text in corpus]

# Train a Word2Vec model
model = Word2Vec(sentences=preprocessed_corpus, vector_size=300, window=5, min_count=1, workers=4)

# Save the model
model.save("word2vec_model.model")

# To load the model later:
# model = Word2Vec.load("word2vec_model.model")

example_word = 'movie'

# Example: Retrieve word vectors
vector = model.wv[example_word]

# Example: Most similar words
similar_words = model.wv.most_similar(example_word, topn=5)

print("Vector for {}:".format(example_word), vector)
print("Most similar words to 'example_word':", similar_words)
# Out:
# Vector for movie: [ 2.67876964e-03 -7.08241889e-04 -2.32462306e-04  7.16871407e-04
#  -1.06130596e-04 -5.43645700e-04  2.56273453e-03  1.56903977e-03
#  -8.88410257e-04 -6.65750704e-04  1.85976410e-03 -2.84594920e-04
#  -2.71135039e-04  3.05756717e-03 -2.30056536e-03 -7.73325097e-04
#   3.51689127e-03  2.10750173e-03  7.11746747e-04 -3.12499399e-03
#  -8.12411890e-05 -9.18560894e-04  3.85384355e-03  4.27828229e-04
#   1.46904273e-03  7.47912563e-04 -1.52392744e-03 -1.54234411e-03
#  -3.42926971e-04 -1.48554018e-03  2.46367953e-03  2.84231105e-03
#  -5.44715382e-04  9.97478492e-04 -2.02301145e-03  7.50728883e-04
#  -1.93469564e-03 -3.90726374e-03 -2.12439196e-03 -3.08508868e-03
#   2.10896600e-03 -1.73417141e-03  2.88549298e-03 -3.14773270e-03
#   1.34515716e-03  3.84120224e-03 -2.33297539e-03 -2.94257654e-03
#  -1.72518962e-03 -3.02660424e-04 -1.11933638e-04 -3.03579750e-03
#  -3.12517164e-03  1.11245946e-03 -2.97484710e-03 -2.23706919e-03
#   2.69370805e-03 -1.39252248e-03  3.62731749e-03 -3.75488249e-04
#  -2.43088766e-03 -2.00250978e-03 -3.52157862e-03 -1.61340355e-03
#   6.67524582e-04  3.17628426e-03  2.48379377e-03 -2.70948536e-03
#   6.42564206e-04  2.40097288e-04 -7.41532189e-04 -3.30517604e-03
#  -3.04199202e-04 -2.49175471e-03  2.78795813e-03 -2.15869234e-03
#   1.16494170e-03  3.79435555e-03 -4.44201287e-04  1.91671634e-03
#  -6.03468041e-04  2.63343798e-03  1.55858975e-03 -4.24432661e-03
#  -7.04735401e-04  5.77110855e-04 -4.29114298e-04 -1.12227790e-04
#  -3.47435591e-04 -1.37059519e-03  2.26385473e-05  1.63261255e-03
#  -1.69753504e-03 -7.28597282e-04  1.60242111e-04  3.43550113e-04
#   3.54102987e-04 -1.63667230e-03  3.52261966e-04 -1.25084887e-03
#   1.76273729e-03  4.89715429e-04  8.16978514e-04 -2.92780809e-03
#  -1.66663283e-03 -1.03436667e-03  3.18139326e-03 -1.47565966e-03
#  -3.74996476e-03 -1.77659051e-04 -1.35439110e-03  2.41129356e-03
#  -3.73272900e-03  1.00232754e-03 -3.50318779e-03  3.61965562e-04
#   2.01842911e-03  2.05434253e-03 -1.65201596e-03 -1.71623798e-03
#  -1.62079325e-03 -2.52752868e-03 -3.72134917e-03 -9.46550455e-04
#   2.06260171e-04 -2.53469963e-03  2.21145782e-03  7.67336576e-04
#   1.93983968e-03  4.33571491e-04 -8.36708001e-04 -2.07169354e-03
#  -6.10800984e-04  2.24186317e-03 -1.79572694e-03  1.25230942e-03
#   1.64961885e-03 -3.44156841e-04  4.00711875e-03  3.98569508e-03
#   6.59166777e-04  1.83205120e-03  2.51667062e-03 -1.86196005e-03]
# Most similar words to 'example_word': [('prison', 0.2545772194862366), ('film', 0.2218804508447647), ('movies', 0.21206888556480408), ('questions', 0.20509257912635803), ('years', 0.20412909984588623)]

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

# Load your dataset from assignment two
# For example, assuming you have a CSV file named 'your_dataset.csv'
df = pd.read_csv('/content/imdb_movie_reviews.csv')

# Assuming you have a 'text' column in your dataset containing the text data
corpus = df['Review'].tolist()

# Initialize SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# Function to get sentiment category
def get_sentiment(text):
    compound_score = sid.polarity_scores(text)['compound']
    if compound_score >= 0.05:
        return 'positive'
    elif compound_score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

# Apply sentiment analysis to each document
df['sentiment'] = df['Review'].apply(get_sentiment)

# Save the annotated dataset to a new CSV file
df.to_csv('annotated_dataset.csv', index=False)

# %% [markdown]
# # The GitHub link of your final csv file
#
# https://github.com/LasyaBobbili/lasyabobbili_info5731_fall2023/blob/main/Sentimental_analysed_dataset.csv
#
#
# # Link:
